# %%
import pandas as pd

df = pd.read_json('foundationFoodsSimplified.json')
print(df.group.value_counts())

plant_rows = df[df['group'].isin(['Vegetable', 'Fruit', 'Nuts/Seeds'])]
print(plant_rows['label'].values)
# Out:
# group
# Vegetable       107
# Fruit            43
# Dairy            42
# Grain            41
# Meat             25
# Nuts/Seeds       19
# Other            18
# Seafood          10
# Spices/Herbs      1
# Oil               1
# Name: count, dtype: int64
# ['Almond butter, creamy'
#  'Apple juice, with added vitamin C, from concentrate, shelf stable'
#  'Apples, fuji, with skin, raw' 'Apples, gala, with skin, raw'
#  'Apples, granny smith, with skin, raw'
#  'Apples, honeycrisp, with skin, raw'
#  'Apples, red delicious, with skin, raw'
#  'Applesauce, unsweetened, with added vitamin C' 'Apricot, with skin, raw'
#  'Arugula, baby, raw' 'Asparagus, green, raw' 'Avocado, Hass, peeled, raw'
#  'Bananas, overripe, raw' 'Bananas, ripe and slightly ripe, raw'
#  'Beans, Dry, Black (0% moisture)' 'Beans, Dry, Brown (0% moisture)'
#  'Beans, Dry, Carioca (0% moisture)' 'Beans, Dry, Cranberry (0% moisture)'
#  'Beans, Dry, Dark Red Kidney (0% moisture)'
# ...
